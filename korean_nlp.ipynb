# %% [markdown]
# ## English analogy

# %% [markdown]
# #### Import Spacy and download english model

# %%
# !python -m spacy download en_core_web_sm

# %%
import spacy

nlp_en = spacy.load("en_core_web_sm")

doc = nlp_en("This is a sentence.")

print([(w.text, w.pos_) for w in doc])
# Out:
# 2023-08-14 13:51:38.938946: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [('This', 'PRON'), ('is', 'AUX'), ('a', 'DET'), ('sentence', 'NOUN'), ('.', 'PUNCT')]

# %% [markdown]
# #### Import Direct English Language module

# %%
import en_core_web_sm

nlp_en = en_core_web_sm.load()

doc = nlp_en("This is a sentence.")

print([(w.text, w.pos_) for w in doc])
# Out:
# [('This', 'PRON'), ('is', 'AUX'), ('a', 'DET'), ('sentence', 'NOUN'), ('.', 'PUNCT')]

# %% [markdown]
# #### Download Korean Spacy model

# %%
# !python -m spacy download ko_core_news_sm
# !pip install -U pkuseg
# !pip install jieba
# !pip install stopwordsiso
# Out:
# Collecting ko-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ko_core_news_sm-3.5.0/ko_core_news_sm-3.5.0-py3-none-any.whl (14.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 1.3 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from ko-core-news-sm==3.5.0) (3.5.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (8.1.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (6.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (1.24.2)
# Requirement already satisfied: pathy>=0.10.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (1.0.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (1.1.1)
# Requirement already satisfied: setuptools in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (65.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (2.28.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (1.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (23.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: jinja2 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (3.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (4.64.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (1.10.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (0.7.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (2.4.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (4.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (1.26.14)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/shashanksahoo/miniconda3/envs/tools/lib/python3.9/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->ko-core-news-sm==3.5.0) (2.1.2)
# Installing collected packages: ko-core-news-sm
# Successfully installed ko-core-news-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ko_core_news_sm')

# %% [markdown]
# #### Import Direct Korean Language module

# %%
import spacy
nlp_ko = spacy.load("ko_core_news_sm")
doc = nlp_ko("모든 사람은 교육을 받을 권리를 가진다 . 교육은 최소한 초등 및 기초단계에서는 무상이어야 한다. 초등교육은 의무적이어야 한다. 기술 및 직업교육은 일반적으로 접근이 가능하여야 하며, 고등교육은 모든 사람에게 실력에 근거하여 동등하게 접근 가능하여야 한다.")
print([(w.text, w.pos_) for w in doc])
# Out:
# [('모든', 'ADJ'), ('사람은', 'NOUN'), ('교육을', 'NOUN'), ('받을', 'VERB'), ('권리를', 'NOUN'), ('가진다', 'VERB'), ('.', 'PUNCT'), ('교육은', 'NOUN'), ('최소한', 'ADV'), ('초등', 'NOUN'), ('및', 'CCONJ'), ('기초단계에서는', 'NOUN'), ('무상이어야', 'VERB'), ('한다', 'AUX'), ('.', 'PUNCT'), ('초등교육은', 'ADV'), ('의무적이어야', 'VERB'), ('한다', 'AUX'), ('.', 'PUNCT'), ('기술', 'NOUN'), ('및', 'CCONJ'), ('직업교육은', 'NOUN'), ('일반적으로', 'ADV'), ('접근이', 'NOUN'), ('가능하여야', 'VERB'), ('하며', 'CCONJ'), (',', 'PUNCT'), ('고등교육은', 'PROPN'), ('모든', 'ADJ'), ('사람에게', 'ADV'), ('실력에', 'CCONJ'), ('근거하여', 'SCONJ'), ('동등하게', 'PROPN'), ('접근', 'NOUN'), ('가능하여야', 'VERB'), ('한다', 'AUX'), ('.', 'PUNCT')]

# %%
import ko_core_news_sm
nlp_ko = ko_core_news_sm.load()
doc = nlp_ko("교육은 인격의 완전한 발전과 인권과 기본적 자유에 대한 존중의 강화를 목표로 한다. 교육은 모든 국가 , 인종 또는 종교 집단간에 이해, 관용 및 우의를 증진하며 , 평화의 유지를 위한 국제연합의 활동을 촉진하여야 한부모는 자녀에게 제공되는 교육의 종류를 선택할 우선권을 가진다")
print([(w.text, w.pos_) for w in doc])
# Out:
# [('교육은', 'NOUN'), ('인격의', 'NOUN'), ('완전한', 'VERB'), ('발전과', 'CCONJ'), ('인권과', 'NOUN'), ('기본적', 'NOUN'), ('자유에', 'ADV'), ('대한', 'VERB'), ('존중의', 'VERB'), ('강화를', 'NOUN'), ('목표로', 'ADV'), ('한다', 'VERB'), ('.', 'PUNCT'), ('교육은', 'NOUN'), ('모든', 'ADJ'), ('국가', 'NOUN'), (',', 'PUNCT'), ('인종', 'NOUN'), ('또는', 'CCONJ'), ('종교', 'NOUN'), ('집단간에', 'VERB'), ('이해', 'NOUN'), (',', 'PUNCT'), ('관용', 'NOUN'), ('및', 'CCONJ'), ('우의를', 'ADV'), ('증진하며', 'CCONJ'), (',', 'PUNCT'), ('평화의', 'NOUN'), ('유지를', 'NOUN'), ('위한', 'VERB'), ('국제연합의', 'NOUN'), ('활동을', 'NOUN'), ('촉진하여야', 'VERB'), ('한부모는', 'PROPN'), ('자녀에게', 'ADV'), ('제공되는', 'VERB'), ('교육의', 'NOUN'), ('종류를', 'NOUN'), ('선택할', 'VERB'), ('우선권을', 'ADV'), ('가진다', 'VERB')]

# %% [markdown]
# #### Linguistic Features - Engineering and extraction

# %%
# parts of speech tagging
for token in doc:
    print(((token.text, 
            token.lemma_, 
            token.pos_, 
            token.tag_,
            token.dep_,
            token.shape_,
            token.is_alpha,
            token.is_stop,
            )))
# Out:
# ('교육은', '교육+은', 'NOUN', 'ncpa+jxt', 'dislocated', 'xxx', True, False)
# ('인격의', '인격+의', 'NOUN', 'ncn+jcm', 'nmod', 'xxx', True, False)
# ('완전한', '완전+하+ㄴ', 'VERB', 'ncps+xsm+etm', 'amod', 'xxx', True, False)
# ('발전과', '발전+과', 'CCONJ', 'ncpa+jcj', 'obj', 'xxx', True, False)
# ('인권과', '인권+과', 'NOUN', 'ncn+xsn', 'conj', 'xxx', True, False)
# ('기본적', '기본+적', 'NOUN', 'ncn+xsn', 'amod', 'xxx', True, False)
# ('자유에', '자유+에', 'ADV', 'ncn+jca', 'obl', 'xxx', True, False)
# ('대한', '대하+ㄴ', 'VERB', 'pvg+etm', 'acl', 'xx', True, False)
# ('존중의', '존중의', 'VERB', 'ncps+xsm+etm', 'amod', 'xxx', True, False)
# ('강화를', '강화+를', 'NOUN', 'ncpa+jco', 'conj', 'xxx', True, False)
# ('목표로', '목표+로', 'ADV', 'ncpa+jca', 'advcl', 'xxx', True, False)
# ('한다', '하+ㄴ다', 'VERB', 'pvg+ef', 'ROOT', 'xx', True, False)
# ('.', '.', 'PUNCT', 'sf', 'punct', '.', False, False)
# ('교육은', '교육+은', 'NOUN', 'ncpa+jxt', 'dislocated', 'xxx', True, False)
# ('모든', '모든', 'ADJ', 'mma', 'amod', 'xx', True, False)
# ('국가', '국가', 'NOUN', 'ncn', 'compound', 'xx', True, False)
# (',', ',', 'PUNCT', 'sp', 'punct', ',', False, False)
# ('인종', '인종', 'NOUN', 'ncn', 'conj', 'xx', True, False)
# ('또는', '또는', 'CCONJ', 'maj', 'cc', 'xx', True, False)
# ('종교', '종교', 'NOUN', 'ncn', 'compound', 'xx', True, False)
# ('집단간에', '집단간에', 'VERB', 'ncn+jp+ep+etm', 'acl', 'xxxx', True, False)
# ('이해', '이해', 'NOUN', 'ncpa', 'conj', 'xx', True, False)
# (',', ',', 'PUNCT', 'sp', 'punct', ',', False, False)
# ('관용', '관용', 'NOUN', 'ncn', 'advcl', 'xx', True, False)
# ('및', '및', 'CCONJ', 'maj', 'cc', 'x', True, False)
# ('우의를', '우의+를', 'ADV', 'ncps+xsa', 'conj', 'xxx', True, False)
# ('증진하며', '증+진+하며', 'CCONJ', 'ncpa+xsv+ecc', 'acl', 'xxxx', True, False)
# (',', ',', 'PUNCT', 'sp', 'punct', ',', False, False)
# ('평화의', '평화+의', 'NOUN', 'ncps+jcm', 'nmod', 'xxx', True, False)
# ('유지를', '유지+를', 'NOUN', 'ncpa+jco', 'obj', 'xxx', True, False)
# ('위한', '위하+ㄴ', 'VERB', 'pvg+etm', 'acl', 'xx', True, False)
# ('국제연합의', '국제연+합+의', 'NOUN', 'ncn+ncn+jcm', 'nmod', 'xxxx', True, False)
# ('활동을', '활동+을', 'NOUN', 'ncpa+jco', 'obj', 'xxx', True, False)
# ('촉진하여야', '촉진+하+어야', 'VERB', 'ncpa+xsv+etm', 'conj', 'xxxx', True, False)
# ('한부모는', '한부모+는', 'PROPN', 'ncn+ncn+jxt', 'dislocated', 'xxxx', True, False)
# ('자녀에게', '자녀+에게', 'ADV', 'ncn+jca', 'advcl', 'xxxx', True, False)
# ('제공되는', '제공+되+는', 'VERB', 'ncpa+xsv+etm', 'acl', 'xxxx', True, False)
# ('교육의', '교육+의', 'NOUN', 'ncpa+jcm', 'nmod', 'xxx', True, False)
# ('종류를', '종류+를', 'NOUN', 'ncn+jco', 'obj', 'xxx', True, False)
# ('선택할', '선택+하+ㄹ', 'VERB', 'ncpa+xsv+etm', 'acl', 'xxx', True, False)
# ('우선권을', '우선+권을', 'ADV', 'nq+jca', 'advcl', 'xxxx', True, False)
# ('가진다', '가지+ㄴ다', 'VERB', 'pvg+etm', 'ROOT', 'xxx', True, False)

# %%
## Output in different ways
for token in doc:
    print('%s_%s' % (token.text, token.tag_))
    
out = ''
for token in doc:
    out = out + ' '+ '/'.join((token.text, token.tag_))
print(out)
# Out:
# 교육은_ncpa+jxt
# 인격의_ncn+jcm
# 완전한_ncps+xsm+etm
# 발전과_ncpa+jcj
# 인권과_ncn+xsn
# 기본적_ncn+xsn
# 자유에_ncn+jca
# 대한_pvg+etm
# 존중의_ncps+xsm+etm
# 강화를_ncpa+jco
# 목표로_ncpa+jca
# 한다_pvg+ef
# ._sf
# 교육은_ncpa+jxt
# 모든_mma
# 국가_ncn
# ,_sp
# 인종_ncn
# 또는_maj
# 종교_ncn
# 집단간에_ncn+jp+ep+etm
# 이해_ncpa
# ,_sp
# 관용_ncn
# 및_maj
# 우의를_ncps+xsa
# 증진하며_ncpa+xsv+ecc
# ,_sp
# 평화의_ncps+jcm
# 유지를_ncpa+jco
# 위한_pvg+etm
# 국제연합의_ncn+ncn+jcm
# 활동을_ncpa+jco
# 촉진하여야_ncpa+xsv+etm
# 한부모는_ncn+ncn+jxt
# 자녀에게_ncn+jca
# 제공되는_ncpa+xsv+etm
# 교육의_ncpa+jcm
# 종류를_ncn+jco
# 선택할_ncpa+xsv+etm
# 우선권을_nq+jca
# 가진다_pvg+etm
#  교육은/ncpa+jxt 인격의/ncn+jcm 완전한/ncps+xsm+etm 발전과/ncpa+jcj 인권과/ncn+xsn 기본적/ncn+xsn 자유에/ncn+jca 대한/pvg+etm 존중의/ncps+xsm+etm 강화를/ncpa+jco 목표로/ncpa+jca 한다/pvg+ef ./sf 교육은/ncpa+jxt 모든/mma 국가/ncn ,/sp 인종/ncn 또는/maj 종교/ncn 집단간에/ncn+jp+ep+etm 이해/ncpa ,/sp 관용/ncn 및/maj 우의를/ncps+xsa 증진하며/ncpa+xsv+ecc ,/sp 평화의/ncps+jcm 유지를/ncpa+jco 위한/pvg+etm 국제연합의/ncn+ncn+jcm 활동을/ncpa+jco 촉진하여야/ncpa+xsv+etm 한부모는/ncn+ncn+jxt 자녀에게/ncn+jca 제공되는/ncpa+xsv+etm 교육의/ncpa+jcm 종류를/ncn+jco 선택할/ncpa+xsv+etm 우선권을/nq+jca 가진다/pvg+etm

# %% [markdown]
# #### Visualization Linguistic Features

# %%
# Visualize
from spacy import displacy
displacy.render(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ko" id="b6d0f663543f484d9716f3f0bc2d2ae8-0" class="displacy" width="6700" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">교육은</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">인격의</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">완전한</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">발전과</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">인권과</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">기본적</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">자유에</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">대한</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">존중의</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">강화를</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">목표로</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">한다.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">교육은</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">모든</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">국가 ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">인종</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">또는</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">종교</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">집단간에</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">이해,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">관용</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">및</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">우의를</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">증진하며 ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">평화의</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">유지를</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">위한</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">국제연합의</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">활동을</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">촉진하여야</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">한부모는</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">PROPN</tspan>
# </text>
#
# <text class="

# %%
options = {"compact": True, "bg": "#09a3d5",
           "color": "white", "font": "Source Sans Pro",
          "distance": 120}
displacy.render(doc, style="dep", options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ko" id="5cffd88ff0a64364a44e46805c5736d4-0" class="displacy" width="4610" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">교육은</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">인격의</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">완전한</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">발전과</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">인권과</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">기본적</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">자유에</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">대한</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">존중의</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">강화를</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">목표로</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">한다.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">교육은</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">모든</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">국가 ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">인종</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">또는</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">종교</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">집단간에</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">이해,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">관용</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">및</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">우의를</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">증진하며 ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">평화의</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">유지를</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">위한</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">국제연합의</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">활동을</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">촉진하여야</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">한부모는</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">PROPN</tspan>
# </text>
#
# <text cla

# %%
## longer paragraphs
text_long = '''武漢肺炎全球肆虐，至今已有2906萬人確診、92萬染疫身亡，而流亡美國的中國大陸病毒學家閻麗夢，14日時開通了推特帳號，並公布一份長達26頁的科學論文，研究直指武肺病毒與自然人畜共通傳染病的病毒不同，並呼籲追查武漢P4實驗室及美國衛生研究院（NIH）之間的金流，引發討論。'''
text_long_list = text_long.split(sep="，")
len(text_long_list)

for c in text_long_list:
    print(c)
# Out:
# 武漢肺炎全球肆虐
# 至今已有2906萬人確診、92萬染疫身亡
# 而流亡美國的中國大陸病毒學家閻麗夢
# 14日時開通了推特帳號
# 並公布一份長達26頁的科學論文
# 研究直指武肺病毒與自然人畜共通傳染病的病毒不同
# 並呼籲追查武漢P4實驗室及美國衛生研究院（NIH）之間的金流
# 引發討論。

# %%
## parse the texts
doc2 = list(nlp_ko.pipe(text_long_list))
len(doc2)
# Out:
# 8

# %%
import jieba
import jieba.posseg as pseg

text = '飞机是今天晚上七点钟准时降落在北京首都国际机场的'

words = pseg.cut(text)
for w in words:
    print('%s %s' % (w.word, w.flag))
# Out:
# 飞机 n
# 是 v
# 今天 t
# 晚上 t
# 七点钟 m
# 准时 v
# 降落 v
# 在 p
# 北京 ns
# 首都国际机场 nt
# 的 uj

# %%
import stopwordsiso
from stopwordsiso import stopwords
kor_stop_words = list(stopwords(["ko"]))  # Chinese

# %%
kor_stop_words
# Out:
# ['할지라도',
#  '하지 않는다면',
#  '이렇게말하자면',
#  '그들',
#  '그리고',
#  '삼',
#  '과연',
#  '할수있다',
#  '하려고하다',
#  '허걱',
#  '아무거나',
#  '이와 같다',
#  '지말고',
#  '하도록시키다',
#  '그위에',
#  '것',
#  '헐떡헐떡',
#  '할 생각이다',
#  '“',
#  '아니라면',
#  '하마터면',
#  '하자마자',
#  '；',
#  '할수있어',
#  '＊',
#  '일지라도',
#  '￥',
#  '어느때',
#  '양자',
#  '관하여',
#  '곧',
#  '자기',
#  '`',
#  '얼마간',
#  '할 따름이다',
#  '４',
#  '을',
#  '및',
#  '비로소',
#  '매번',
#  '통하여',
#  '때가 되어',
#  '그래서',
#  '인젠',
#  '。',
#  '이지만',
#  '한데',
#  '다음으로',
#  '모두',
#  '그러면',
#  '향하다',
#  '안 그러면',
#  '전자',
#  '알 수 있다',
#  '시작하여',
#  '윙윙',
#  '이었다',
#  '요만한 것',
#  '모',
#  '응당',
#  '위해서',
#  '하기는한데',
#  '아니나다를가',
#  '1',
#  '인 듯하다',
#  '하는 김에',
#  '단지',
#  '그',
#  '어느해',
#  '6',
#  '이와 반대로',
#  '봐라',
#  '그리하여',
#  '지든지',
#  '&',
#  '에게',
#  '｛',
#  '삐걱거리다',
#  '부터',
#  '그렇지않으면',
#  '5',
#  '＠',
#  '+',
#  '으로써',
#  '했어요',
#  '어느',
#  '이와같다면',
#  '"',
#  '<',
#  '자',
#  '겸사겸사',
#  '잇따라',
#  '하기 때문에',
#  '이천칠',
#  '로 인하여',
#  '대해 말하자면',
#  '비교적',
#  '입장에서',
#  '라 해도',
#  '꽈당',
#  '｜',
#  '하나',
#  '헉헉',
#  '잠시',
#  '중의하나',
#  '８',
#  '말할것도 없고',
#  '휘익',
#  '개의치않고',
#  '둥둥',
#  '《',
#  '다시 말하자면',
#  '무렵',
#  '하고 있다',
#  '버금',
#  '뒤이어',
#  '바꿔 말하면',
#  '논하지 않다',
#  '좀',
#  '우선',
#  '뿐만아니라',
#  '어떠한',
#  '위에서 서술한바와같이',
#  '탕탕',
#  '이러한',
#  '3',
#  '시간',
#  '，',
#  '육',
#  '좍좍',
#  '까지 미치다',
#  '６',
#  '콸콸',
#  '*',
#  '게다가',
#  '물론',
#  '셋',
#  '시초에',
#  '우르르',
#  '바꾸어서 말하면',
#  '할뿐',
#  '할 줄 안다',
#  '같다',
#  '해야한다',
#  '앗',
#  '그러나',
#  '소인',
#  '보다더',
#  '너희들',
#  '이어서',
#  '설사',
#  '왜',
#  '불구하고',
#  '륙',
#  '~',
#  '예',
#  '이 되다',
#  '이 때문에',
#  '아이야',
#  '하지마',
#  '구체적으로',
#  '저것만큼',
#  '운운',
#  '의거하여',
#  '월',
#  '혹은',
#  '흥',
#  '그러한즉',
#  '가까스로',
#  '조차',
#  '영',
#  '=',
#  '나머지는',
#  '여전히',
#  '아하',
#  '말하자면',
#  '—',
#  '이젠',
#  '뿐만 아니라',
#  '아이고',
#  '》',
#  '고려하면',
#  '이 외에',
#  '더라도',
#  '끼익',
#  '다른 방면으로',
#  '여차',
#  '어찌됏든',
#  '붕붕',
#  '어',
#  '나',
#  '보는데서',
#  '불문하고',
#  '하하',
#  '게우다',
#  '우리들',
#  '퉤',
#  '에 한하다',
#  '설령',
#  '아',
#  '년',
#  '해봐요',
#  '타다',
#  '［',
#  '자기집',
#  '이렇게되면',
#  '그렇지만',
#  '어쨋든',
#  '헉',
#  '둘',
#  '때문에',
#  '허허',
#  '따라',
#  '각',
#  '놀라다',
#  '바꾸어서 한다면',
#  '오직',
#  '여부',
#  '쳇',
#  '하는것도',
#  '하지 않도록',
#  '!',
#  '어이',
#  '아니었다면',
#  '이라면',
#  '요만큼',
#  '여기',
#  '그런 까닭에',
#  '대하여',
#  '오자마자',
#  '＄',
#  '％',
#  '——',
#  '더욱이는',
#  '의',
#  '하면된다',
#  '）',
#  '아야',
#  '한마디',
#  '해도된다',
#  ')',
#  '하곤하였다',
#  '조차도',
#  '저희',
#  '허',
#  '아이쿠',
#  '습니다',
#  '와 같은 사람들',
#  '더군다나',
#  '＋',
#  '팍',
#  '이러이러하다',
#  '0',
#  '제',
#  '하지만',
#  '얼마',
#  '～',
#  '차라리',
#  '?',
#  '(',
#  '요만한걸',
#  '즉',
#  '중에서',
#  '설마',
#  '아래윗',
#  '이천팔',
#  '만약',
#  '으로서',
#  '이 밖에',
#  '뿐이다',
#  '팔',
#  '든간에',
#  '여러분',
#  '쉿',
#  '이와 같은',
#  '오르다',
#  '.',
#  '일때',
#  '저것',
#  '５',
#  '구토하다',
#  '반대로 말하자면',
#  '까지도',
#  '이쪽',
#  '일반적으로',
#  '%',
#  '거니와',
#  '２',
#  '어느것',
#  '시키다',
#  '할줄알다',
#  '이럴정도로',
#  '오로지',
#  '비추어 보아',
#  '생각한대로',
#  '이천구',
#  '‘',
#  '한항목',
#  '］',
#  '_',
#  '·',
#  '않기 위해서',
#  '한 까닭에',
#  '까지',
#  '대해서',
#  '이로 인하여',
#  '그럼에도 불구하고',
#  '마저',
#  '펄렁',
#  '３',
#  '누구',
#  '에서',
#  '8',
#  '끙끙',
#  '관계가 있다',
#  '넷',
#  '어때',
#  '토하다',
#  '형식으로 쓰여',
#  '이것',
#  '무릎쓰고',
#  '때',
#  '칠',
#  '등',
#  '막론하고',
#  '？',
#  '다소',
#  '어떤',
#  '이런',
#  '다시말하면',
#  '여섯',
#  '마저도',
#  '＜',
#  '얼마나',
#  '졸졸',
#  '아무도',
#  '예를 들면',
#  '두번째로',
#  '누가 알겠는가',
#  '당장',
#  '만은 아니다',
#  '4',
#  '기타',
#  '알았어',
#  '따라서',
#  '하느니',
#  '기대여',
#  '〈',
#  '엉엉',
#  '하면 할수록',
#  '총적으로',
#  '하는것이 낫다',
#  '어느쪽',
#  '딱',
#  '한다면 몰라도',
#  '이렇게 많은 것',
#  '다만',
#  '응',
#  '어째서',
#  '요컨대',
#  '|',
#  '하도록하다',
#  '９',
#  '참',
#  '과',
#  '이 정도의',
#  '어디',
#  '에 가서',
#  '야',
#  '^',
#  '어찌됏어',
#  '어느 년도',
#  '...',
#  '：',
#  '앞의것',
#  '다음',
#  '정도에 이르다',
#  '상대적으로 말하자면',
#  '＆',
#  '까닭으로',
#  '비걱거리다',
#  '앞에서',
#  '이번',
#  '할만하다',
#  '근거로',
#  '비하면',
#  '즉시',
#  '쾅쾅',
#  '그럼',
#  '첫번째로',
#  '총적으로 보면',
#  '…',
#  '남짓',
#  '제각기',
#  '비록',
#  '마치',
#  '댕그',
#  '우리',
#  '우에 종합한것과같이',
#  '결론을 낼 수 있다',
#  '한켠으로는',
#  '흐흐',
#  '하구나',
#  '와아',
#  '얼마 안 되는 것',
#  '딩동',
#  '아이구',
#  '좋아',
#  '자마자',
#  '가',
#  '에 대해',
#  '결과에 이르다',
#  '로부터',
#  '근거하여',
#  '기준으로',
#  '\\',
#  '휴',
#  '힘입어',
#  '오',
#  '하겠는가',
#  '또',
#  '잠깐',
#  '같이',
#  '더불어',
#  '해서는 안된다',
#  '관해서는',
#  '까악',
#  '함께',
#  '뚝뚝',
#  '2',
#  '관련이 있다',
#  '로써',
#  '그중에서',
#  '연이서',
#  '것들',
#  '이',
#  '한 후',
#  '｝',
#  '하여금',
#  '어찌하든지',
#  ',',
#  '된바에야',
#  '한적이있다',
#  '기점으로',
#  "'",
#  '오히려',
#  '약간',
#  '다수',
#  '봐',
#  '〉',
#  '그만이다',
#  '만약에',
#  '이르기까지',
#  '자신',
#  '어떻해',
#  '틈타',
#  '”',
#  '각종',
#  '령',
#  '얼마든지',
#  '다른',
#  '혹시',
#  '결국',
#  '대로 하다',
#  '더욱더',
#  '등등',
#  '입각하여',
#  '전후',
#  '오호',
#  '하더라도',
#  '향하여',
#  '퍽',
#  '밖에 안된다',
#  '어떤것들',
#  '얼마만큼',
#  '쪽으로',
#  '그래',
#  '툭',
#  '하든지',
#  '１',
#  '하기만 하면',
#  '하게하다',
#  '이만큼',
#  '그저',
#  '이래',
#  '하지마라',
#  '하고있었다',
#  '반드시',
#  '구',
#  '갖고말하자면',
#  '임에 틀림없다',
#  '다음에',
#  '저쪽',
#  '각자',
#  '일것이다',
#  '참나',
#  '그렇지 않다면',
#  '아니면',
#  '이렇구나',
#  '만일',
#  '않기 위하여',
#  '공동으로',
#  '아니',
#  '혼자',
#  '하여야',
#  '답다',
#  '７',
#  '０',
#  '그치지 않다',
#  '바와같이',
#  '외에도',
#  '그렇게 함으로써',
#  '어느곳',
#  '남들',
#  '바로',
#  '이리하여',
#  '어찌하여',
#  '비슷하다',
#  '그러니까',
#  '그러니',
#  '만 못하다',
#  '어기여차',
#  '의해서',
#  '이유만으로',
#  '해요',
#  '된이상',
#  '총적으로 말하면',
#  '이외에도',
#  '와',
#  '전부',
#  '>',
#  '이곳',
#  '제외하고',
#  '진짜로',
#  '하면서',
#  '어떻게',
#  '더구나',
#  '도달하다',
#  '무엇',
#  '여덟',
#  '이천육',
#  '견지에서',
#  '본대로',
#  '심지어',
#  '줄은모른다',
#  '거의',
#  '동안',
#  '것과 같이',
#  '그러므로',
#  '어떤것',
#  '그래도',
#  '、',
#  '만큼',
#  '예하면',
#  '일',
#  '하는것만 못하다',
#  '무슨',
#  '점에서 보아',
#  '조금',
#  '실로',
#  '여',
#  '9',
#  '를',
#  '겨우',
#  '하는 편이 낫다',
#  '하기에',
#  '할망정',
#  '사',
#  '소생',
#  '삐걱',
#  '따지지 않다',
#  '！',
#  '향해서',
#  '들',
#  '위하여',
#  '지만',
#  '네',
#  '관계없이',
#  '또한',
#  '반대로',
#  '로',
#  '일곱',
#  '훨씬',
#  '이봐',
#  '언제',
#  '아이',
#  '여보시오',
#  '언젠가',
#  '어쩔수 없다',
#  '해도좋다',
#  '바꾸어말하자면',
#  '그렇지',
#  '바꾸어말하면',
#  '하기 위하여',
#  '할지언정',
#  '메쓰겁다',
#  '와르르',
#  '따위',
#  '얼마큼',
#  '의해',
#  '아홉',
#  '어찌',
#  '뒤따라',
#  '＃',
#  '가령',
#  '에',
#  '그때',
#  '의지하여',
#  '하기보다는',
#  '부류의 사람들',
#  '줄은 몰랏다',
#  '’',
#  '에 있다',
#  '으로 인하여',
#  '예컨대',
#  '＞',
#  '저기',
#  '옆사람',
#  '다섯',
#  '쿵',
#  '대하면',
#  '하게될것이다',
#  '하물며',
#  '몇',
#  '연관되다',
#  '할 힘이 있다',
#  '너',
#  '즈음하여',
#  '（',
#  '주룩주룩',
#  '︿',
#  '타인',
#  '주저하지 않고',
#  ';',
#  '동시에',
#  '아울러',
#  '그에 따르는',
#  '7',
#  '도착하다',
#  '영차',
#  '예를 들자면',
#  '하는바',
#  '비길수 없다',
#  '하도다',
#  '저',
#  '왜냐하면',
#  '의해되다',
#  '거바',
#  '만이 아니다',
#  '에 달려 있다',
#  '이용하여',
#  '한 이유는',
#  '그렇지 않으면',
#  '일단',
#  '@',
#  '고로',
#  '마음대로',
#  '무엇때문에',
#  '있다',
#  '당신',
#  '그런즉',
#  '보드득',
#  '습니까',
#  '한다면',
#  '관한',
#  '-',
#  '각각',
#  '그런데',
#  '솨',
#  '으로',
#  '이때',
#  '하',
#  '이상',
#  '할때',
#  '할 지경이다',
#  '너희',
#  '시각',
#  '$',
#  '매']

# %%
# import pickle

# with open('kor_stop_words.txt', 'wb') as f:
#     pickle.dump(kor_stop_words, f)

# %%
with open("kor_stop_words.txt","wt") as file:
    for thestring in kor_stop_words:
        print(thestring, file=file)

# %% [markdown]
# ## References
#
# 1. https://pypi.org/project/jieba/
# 2. https://spacy.io/models/ko/
